# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv("../../data/hour.csv")
pd.isnull(df).any()
# Out:
# instant       False
# dteday        False
# season        False
# yr            False
# mnth          False
# hr            False
# holiday       False
# weekday       False
# workingday    False
# weathersit    False
# temp          False
# atemp         False
# hum           False
# windspeed     False
# casual        False
# registered    False
# cnt           False
# dtype: bool

# %%
df.shape
# Out:
# (17379, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.describe(include='all')
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-12-22           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %%
df[['casual','registered','cnt']].describe(include='all')
# Out:
#              casual    registered           cnt
# count  17379.000000  17379.000000  17379.000000
# mean      35.676218    153.786869    189.463088
# std       49.305030    151.357286    181.387599
# min        0.000000      0.000000      1.000000
# 25%        4.000000     34.000000     40.000000
# 50%       17.000000    115.000000    142.000000
# 75%       48.000000    220.000000    281.000000
# max      367.000000    886.000000    977.000000

# %%
df.columns
# Out:
# Index([u'instant', u'dteday', u'season', u'yr', u'mnth', u'hr', u'holiday',
#        u'weekday', u'workingday', u'weathersit', u'temp', u'atemp', u'hum',
#        u'windspeed', u'casual', u'registered', u'cnt'],
#       dtype='object')

# %%
df.columns = ['Instant','Date','Season','Year','Month','Hour','Holiday','Weekday','Workingday','Weather_Condition','Normalized_Temperature','Normalized_Feels_Temperture','Huumidity','Windspeed','Casual','Registered','Demand']

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] += pd.to_timedelta(df['Hour'], unit='h')
df.index = df['Date']
del df['Date']
del df['Instant']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17379 entries, 2011-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 15 columns):
# Season                         17379 non-null int64
# Year                           17379 non-null int64
# Month                          17379 non-null int64
# Hour                           17379 non-null int64
# Holiday                        17379 non-null int64
# Weekday                        17379 non-null int64
# Workingday                     17379 non-null int64
# Weather_Condition              17379 non-null int64
# Normalized_Temperature         17379 non-null float64
# Normalized_Feels_Temperture    17379 non-null float64
# Huumidity                      17379 non-null float64
# Windspeed                      17379 non-null float64
# Casual                         17379 non-null int64
# Registered                     17379 non-null int64
# Demand                         17379 non-null int64
# dtypes: float64(4), int64(11)
# ...

# %%
#df["Workingday"] = np.where(df["Workingday"] == 1, True, False)

# %%
cd = df[df['Casual']>df['Registered']]
plt.bar(cd['Weekday'],cd['Casual'],color='c')
plt.bar(cd['Weekday'],cd['Registered'],color='y')
plt.xlabel('Weekday')
plt.ylabel('Demand For Bikes')
plt.title('Days with higher Casual Demand')
plt.legend(labels=["Casual", "Registered"])
savefig('../../plot/img/casual_demand_greaterthan_registered_demand.png', bbox_inches='tight')
plt.show()

# %%
df['Part_Of_Day'] = pd.cut(np.array(df['Hour']),6, labels=[0,1,2,3,4,5])
df.head()
# Out:
#                      Season  Year  Month  Hour  Holiday  Weekday  Workingday  \
# Date
# 2011-01-01 00:00:00       1     0      1     0        0        6           0
# 2011-01-01 01:00:00       1     0      1     1        0        6           0
# 2011-01-01 02:00:00       1     0      1     2        0        6           0
# 2011-01-01 03:00:00       1     0      1     3        0        6           0
# 2011-01-01 04:00:00       1     0      1     4        0        6           0
#
#                      Weather_Condition  Normalized_Temperature  \
# Date
# 2011-01-01 00:00:00                  1                    0.24
# 2011-01-01 01:00:00                  1                    0.22
# 2011-01-01 02:00:00                  1                    0.22
# 2011-01-01 03:00:00                  1                    0.24
# 2011-01-01 04:00:00                  1                    0.24
#
#                      Normalized_Feels_Temperture  Huumidity  Windspeed  \
# Date
# ...

# %%
sns.set_style("white")
r = np.arange(7)
reg = df.groupby(['Weekday']).Registered.mean()
cas = df.groupby(['Weekday']).Casual.mean()
barWidth = 0.85
opacity = 0.4
totals = [i+j for i,j in zip(reg, cas)]
registered = [i / j * 100 for i,j in zip(reg, totals)]
casual = [i / j * 100 for i,j in zip(cas, totals)]

plt.bar(r, registered, bottom=casual, color='orange', alpha=opacity,edgecolor='white', width=barWidth)
plt.bar(r, casual, color='green', edgecolor='white', alpha=opacity,width=barWidth)

plt.xticks(r,('Sun','Mon','Tue','Wed','Thu','Fri','Sat'))
plt.xlabel('Weekday')
plt.ylabel('Demand For Bikes in %')
plt.title('Casual and Registered Weekday Demand in %')
plt.legend(labels=["Registered","Casual"],loc=2,bbox_to_anchor=(1,1),ncol=1)
savefig('../../plot/img/mean_casual_registered_demand_percent.png', bbox_inches='tight')
plt.show()

# %%
fig, ax = subplots()

index = np.arange(7)
bar_width = 0.35
opacity = 0.4
ax.bar(index, df.groupby(['Weekday']).Registered.mean(), bar_width,
                alpha=opacity, color='b')
ax.bar(index + bar_width, df.groupby(['Weekday']).Casual.mean(), bar_width,
                alpha=opacity, color='r')

ax.set_xlabel('Weekday')
ax.set_ylabel('Demand For Bikes')
ax.set_title('Casual and Registered Weekday Demand')
ax.set_xticklabels(('Sun','Mon','Tue','Wed','Thu','Fri','Sat'))
ax.legend(labels=["Registered","Casual"],loc=2)
ax.set_xticks(index + bar_width / 2)
plt.xticks(rotation=45)
fig.tight_layout()
savefig('../../plot/img/mean_casual_registered_demand.png', bbox_inches='tight')
plt.show()

# %%
fig, ax = subplots()

index = np.arange(24)
bar_width = 0.35
opacity = 0.4
ax.bar(index, df.groupby(['Hour']).Registered.mean(), bar_width,
                 color='orange')
ax.bar(index + bar_width, df.groupby(['Hour']).Casual.mean(), bar_width,
                 color='green')

ax.set_xlabel('Hour')
ax.set_ylabel('Demand For Bikes')
ax.set_title('Casual and Registered Hourly Demand')
ax.legend(labels=["Registered","Casual"],loc=0)
ax.set_xticks(np.arange(24))
plt.xticks(rotation=45)
fig.tight_layout()
savefig('../../plot/img/mean_casual_registered_hourly_demand.png', bbox_inches='tight')
plt.show()

# %%
sns.set_style("white")
fig, ax = subplots()
index = np.arange(6)
bar_width = 0.50
ax.bar(index, df.groupby(['Part_Of_Day']).Demand.mean(), bar_width,color='grey')
ax.set_xlabel('Period')
ax.set_ylabel('Average Demand For Bikes')
ax.set_title('Demand for Bikes during different hourly windows')
ax.set_xticklabels(('0-4','4-8','8-12','12-16','16-20','20-23'))
ax.set_xticks(index + bar_width/10)
fig.tight_layout()
savefig('../../plot/img/demand_in_parts_of_day.png', bbox_inches='tight')
plt.show()

# %%
#pf = df.pivot(columns='Weather_Condition',values='Demand')
#pf.head()

# %%
#pf = pf.fillna(0)
#pf.head()
